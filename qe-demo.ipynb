# %% [markdown]
# ### Query Earth

# %%
import sys
sys.path.append(r"D:\Code\query-earth\dlpk")

import queryearth

qe = queryearth.QueryEarth()
qe.initialize()
# Out:
# Loading demographic GeoParquet...
# Loading local text embedder (sentence-transformers/all-MiniLM-L6-v2)...
# cuda
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Initializing OpenCLIP text encoder...
# Loading POI GeoParquet...
# Loading POI amenity embeddings...

# %%
gdf = qe.predict("Find cafes offering outdoor seating in younger census block groups in San Jose")
# Out:
# Raw content: a = geocode("San Jose")
# b = demo(a, "younger census block groups")
# output = poi(b, "coffee shops with outdoor seating")
# Generated a plan in 3.675015926361084 sec, the plan is: QueryPlan(steps=[PipelineStep(step_id=1, operation='geocode', parameters={'target': 'San Jose', 'resolution': None, 'buffer_distance_km': None}, inputs=[], output_variable='a'), PipelineStep(step_id=2, operation='demo', parameters={'target': 'younger census block groups', 'resolution': None, 'buffer_distance_km': None}, inputs=['a'], output_variable='b'), PipelineStep(step_id=3, operation='poi', parameters={'target': 'coffee shops with outdoor seating', 'resolution': None, 'buffer_distance_km': None}, inputs=['b'], output_variable='FINAL_ANSWER')], raw={'dsl': 'a = geocode("San Jose")\nb = demo(a, "younger census block groups")\noutput = poi(b, "coffee shops with outdoor seating")'})
# [step 1] geocode
#   -> 'a': 1 feature(s)
# [step 2] demo
#   -> 'b': 30 feature(s)
# [step 3] poi
# Matched 2 amenity class(es) above 0.48: ['cafe', 'outdoor_seating']
#   -> 'FINAL_ANSWER': 284 feature(s)
# Executed the plan in 1786598453.822691 sec.

# %%
gdf.to_file(rf"C:\Users\sus14836\Downloads\results.shp")

# %% [markdown]
# ---
